# %% [markdown]
# <a href="https://colab.research.google.com/github/phuongcodes2025-sys/CHAPTER-4/blob/main/Copy_of_functions_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def get_number _from_user(message0:)
    while True :
        try:
            number = int(input(message))
            return number
        except ValueError:
            print("Hey stupid, I said an integer")
def even_or_odd(x)
    if x % 2 == 0:
          return "even"
    else:
        return "odd"
def print_num(x)
    print("%.2f % x)")
